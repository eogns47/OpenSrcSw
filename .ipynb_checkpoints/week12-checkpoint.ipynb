# %%
import csv
f=open("seoul_weather.csv",'r',encoding="cp949")
data=csv.reader(f,delimiter=',')
print(next(f))


mxWeather=-999
mxW_date=''
mnWeather=999
mnW_date=''
mxDTC=-999
mxDTC_date=''

for i in data:
    for j in range(3,5):
        i[j]=float(i[j])
    DTC=i[4]-i[3]
    if DTC>mxDTC:
        mxDTC=DTC
        mxDTC_date=i[0]
    if i[4]>mxWeather:
        mxWeather=i[4]
        mxW_date=i[0]
    if i[3]<mnWeather:
        mnWeather=i[3]
        mnW_date=i[0]
f.close()
print( "최고기온이 가장 높은 날은: ",mxW_date,"기온:",mxWeather,"\n최저기온이 가장 낮은 날은: ",
       mnW_date,"기온:",mnWeather,"\n일교차가 가장 심한 날은 ", mxDTC_date,"일교차:",mxDTC)
# Out:
# 날짜,지점,평균기온(℃),최저기온(℃),최고기온(℃)
#
# 최고기온이 가장 높은 날은:  2021-07-24 기온: 36.5
# 최저기온이 가장 낮은 날은:  2021-01-08 기온: -18.6
# 일교차가 가장 심한 날은  2021-04-21 일교차: 17.9

# %%
import copy

f2=open("subway_fee2.csv")
data3=csv.reader(f2,delimiter=',')
next(data3)

a=list(range(99))
n=0

mx=0
mx2=0
mx3=0
mn=9999999
mn2=9999999
mn3=9999999

mx_station=''
mx2_station=''
mx3_station=''
mn_station=''
mn2_station=''
mn3_station=''



for row in data3:
    for i in range(4,6):
        row[i]=row[i].replace(",","")
        row[i]=float(row[i])
        
    user=row[4]+row[5]
    
    if(a[n]!=row[1]):
        n+=1
        a[n]=row[1]
        if(mx!=0):
            print(a[n-1],"역 중 이용객이 가장 많은 역 순위",mx_station,mx2_station,mx3_station)
            mx=0
            mx2=0
            mx3=0
            print(a[n-1],"역 중 이용객이 가장 적은 역 순위",mn_station,mn2_station,mn3_station,"\n")
            mn=9999999
            mn2=9999999
            mn3=9999999

    if user>mx:
        mx3=mx2; mx3_station=mx2_station
        mx2=mx; mx2_station=mx_station
        mx=user; mx_station=row[3]
    elif user>mx2:
        mx3=mx2; mx3_station=mx2_station
        mx2=user; mx2_station=row[3]
    elif user>mx3:
        mx3=user; mx3_station=row[3]
    
    if user<mn:
        mn3=mn2; mn3_station=mn2_station
        mn2=mn; mn2_station=mn_station
        mn=user; mn_station=row[3]
    elif user<mn2:
        mn3=mn2; mn3_station=mn2_station
        mn2=user; mn2_station=row[3]
    elif user<mn3:
        mn3=user; mn3_station=row[3]
        
    
    

f2.close()
# Out:
# 1호선 역 중 이용객이 가장 많은 역 순위 서울역 종각 종로3가
# 1호선 역 중 이용객이 가장 적은 역 순위 동묘앞 동대문 신설동
#
# 2호선 역 중 이용객이 가장 많은 역 순위 강남 잠실(송파구청) 신림
# 2호선 역 중 이용객이 가장 적은 역 순위 도림천 신답 용두(동대문구청)
#
# 3호선 역 중 이용객이 가장 많은 역 순위 고속터미널 양재(서초구청) 연신내
# 3호선 역 중 이용객이 가장 적은 역 순위 충무로 학여울 무악재
#
# 4호선 역 중 이용객이 가장 많은 역 순위 수유(강북구청) 혜화 쌍문
# 4호선 역 중 이용객이 가장 적은 역 순위 남태령 동작(현충원) 삼각지
#
# 경부선 역 중 이용객이 가장 많은 역 순위 영등포 수원 용산
# 경부선 역 중 이용객이 가장 적은 역 순위 직산 서동탄 진위
#
# 경인선 역 중 이용객이 가장 많은 역 순위 부천 부평 역곡
# 경인선 역 중 이용객이 가장 적은 역 순위 도원 인천 도화
#
# 경원선 역 중 이용객이 가장 많은 역 순위 의정부 청량리(서울시립대입구) 왕십리(성동구청)
# 경원선 역 중 이용객이 가장 적은 역 순위 창동 옥수 보산
#
# 안산선 역 중 이용객이 가장 많은 역 순위 중앙 산본 상록수
# 안산선 역 중 이용객이 가장 적은 역 순위 신길온천 수리산 반월
#
# 과천선 역 중 이용객이 가장 많은 역 순위 범계 인덕원 평촌
# 과천선 역 중 이용객이 가장 적은 역 순위 대공원 경마공원 과천
#
# 분당선 역 중 이용객이 가장 많은 역 순위 야탑 서현 압구정로데오
# 분당선 역 중 이용객이 가장 적은 역 순위 복정 구룡 보정
#
# 일산선 역 중 이용객이 가장 많은 역 순위 삼송 화정 대화
# 일산선 역 중 이용객이 가장 적은 역 순위 지축 대곡 마두
#
# 중앙선 역 중 이용객이 가장 많은 역 순위 회기 구리 도농
# 중앙선 역 중 이용객이 가장 적은 역 순위 지평 신원 오빈
#
# 장항선 역 중 이용객이 가장 많은 역 순위 온양온천 아산 쌍용(나사렛대)
# 장항선 역 중 이용객이 가장 적은 역 순위 탕정 배방 봉명
#
# 경의선 역 중 이용객이 가장 많은 역 순위 일산 행신 탄현
# 경의선 역 중 이용객이 가장 적은 역 순위 검암 계양 임진강
#
# 경춘선 역 중 이용객이 가장 많은 역 순위 평내호평 마석 퇴계원
# 경춘선 역 중 이용객이 가장 적은 역 순위 굴봉산 백양리 상천
#
# 수인선 역 중 이용객이 가장 많은 역 순위 인하대 인천논현 소래포구
# 수인선 역 중 이용객이 가장 적은 역 순위 달월 야목 어천
#
# 경강선 역 중 이용객이 가장 많은 역 순위 경기광주 판교 초월
# 경강선 역 중 이용객이 가장 적은 역 순위 세종대왕릉 이매 신둔도예촌
#
# 5호선 역 중 이용객이 가장 많은 역 순위 광화문(세종문화회관) 까치산 화곡
# 5호선 역 중 이용객이 가장 적은 역 순위 동대문역사문화공원(DDP) 오금 영등포구청
#
# 6호선 역 중 이용객이 가장 많은 역 순위 응암 공덕 망원
# 6호선 역 중 이용객이 가장 적은 역 순위 신내 연신내 버티고개
#
# 7호선 역 중 이용객이 가장 많은 역 순위 가산디지털단지 학동 광명사거리
# 7호선 역 중 이용객이 가장 적은 역 순위 장암 부천종합운동장 삼산체육관
#
# 8호선 역 중 이용객이 가장 많은 역 순위 문정 암사 장지
# 8호선 역 중 이용객이 가장 적은 역 순위 남위례 모란 신흥
#
# 9호선 역 중 이용객이 가장 많은 역 순위 신논현 노량진 여의도
# 9호선 역 중 이용객이 가장 적은 역 순위 구반포 동작(현충원) 개화
#
# 공항철도 1호선 역 중 이용객이 가장 많은 역 순위 디지털미디어시티 홍대입구 김포공항
# 공항철도 1호선 역 중 이용객이 가장 적은 역 순위 인천공항2터미널 공항화물청사 공덕
#
# 9호선2~3단계 역 중 이용객이 가장 많은 역 순위 봉은사 언주 선정릉
# 9호선2~3단계 역 중 이용객이 가장 적은 역 순위 둔촌오륜 한성백제 종합운동장
